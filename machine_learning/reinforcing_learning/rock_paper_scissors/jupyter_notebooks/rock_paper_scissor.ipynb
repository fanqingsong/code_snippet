# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class Bot(object):
    # our states can be either "ROCK, PAPER or SCISSORS"
    state_space = 3
    # three actions by our player
    action_space = 3
    q_table = np.random.uniform(low = -2, high = 5, size = (3, 3))
    total_reward, reward = 0,0
    avg_rewards_list = []
    avg_reward = 0
    result = 'DRAW'
    tags = ["ROCK", "PAPER", "SCISSORS"]
    # looses to map
    loses_to = {
       "0": 1, # rock loses to paper
       "1": 2,  # paper loses to scissor
       "2": 0  # scissor loses to rock
    }
    
    def __init__(self, alpha=0.5, gamma=0.2, epsilon=0.8, min_eps=0, episodes=50):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.min_eps = min_eps
        self.episodes = episodes
        # Calculate episodic reduction in epsilon
        self.reduction = (epsilon - min_eps) / episodes
        
    # either explore or exploit, any which ways return the next action
    def bot_move(self, player_move):
        action = 0
        # Determine next action - epsilon greedy strategy
        if np.random.random() < 1 - self.epsilon:
            print("Exploiting....")
            action = np.argmax(self.q_table[player_move])
        else:
            print("Exploring.....")
            action = np.random.randint(0, self.action_space)
        # Decay epsilon
        if self.epsilon > self.min_eps:
            self.epsilon -= self.reduction
        print("choose ",self.tags[action])
        return action
    
    def get_reward(self, player, bot):
        reward = 0
        if self.get_result(player, bot) == 'WIN':
            reward = 5
        
        elif self.get_result(player, bot) == 'LOSE':
            reward = -2
            
        else:
            # Draw case
            reward = 4
            
        return reward
    
    # update q_table
    def update_experience(self, state, action, reward):
        delta = self.alpha * (reward + self.gamma * np.max(self.q_table[action]) - self.q_table[state,action])
        self.q_table[state,action] += delta
    
    def print_stats(self, player, bot, reward):
        print("Player move : {0}, bot: {1}, reward: {2}, result: {3}, total_reward: {4}".format(self.tags[player], self.tags[bot], reward, self.result, self.total_reward))
        print(self.q_table)
        pass
    
    # returns either a WIN, LOSE or a DRAW to indicate the same.
    def get_result(self, player_move, bot_move):
        if bot_move == player_move:
            self.result = 'DRAW'
        elif self.loses_to[str(bot_move)] == player_move :
            self.result = 'LOSE'
        else:
            self.result = 'WIN'
            
        return self.result    
            
    def get_avg_rewards(self):
        return self.avg_rewards_list
    
    def play(self, player_move):
        # add reward
        bot_move = self.bot_move(player_move)
        reward = self.get_reward(player_move, bot_move)
        self.total_reward += reward
        self.avg_rewards_list.append(reward)
        # update experience
        self.update_experience(player_move, bot_move, reward)
        self.print_stats(player_move, bot_move, reward)

class Game(object):

    def __init__(self, bot, episodes=200):
        self.bot = bot
        self.episodes = episodes
    
    def begin(self):
        player_moves = self.generate_fake_moves(True)
        for idx in range(0, self.episodes):
            self.bot.play(player_moves[idx])
        # Plot Rewards
#         plt.plot(np.arange(len(self.bot.get_avg_rewards())) + 1)
#         plt.savefig('rewards.png')     
#         plt.close()

    def generate_fake_moves(self, fake_moves):
        player_moves = []
        for i in range(0, self.episodes):
            if fake_moves:
                player_moves.append(np.random.randint(0, 3))
            else:
                self.read_player_move()
        return player_moves

    def read_player_move(self):
        return int(input("Enter your move (0- Rock, 1 - paper, 2- scissors): "))

game = Game(Bot())
game.begin()
# Out:
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 5
# [[ 4.78310516  0.27437983  2.79928639]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 4.89040196  3.26894488 -1.50504946]]
# Exploring.....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 10
# [[ 4.78310516  0.27437983  2.79928639]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 5.4235115   3.26894488 -1.50504946]]
# Exploring.....
# choose  SCISSORS
# Player move : ROCK, bot: SCISSORS, reward: -2, result: LOSE, total_reward: 8
# [[ 4.78310516  0.27437983  0.94199435]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 5.4235115   3.26894488 -1.50504946]]
# Exploring.....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 12
# [[ 4.8698631   0.27437983  0.94199435]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 5.4235115   3.26894488 -1.50504946]]
# Exploring.....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 16
# [[ 4.92191786  0.27437983  0.94199435]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 5.4235115   3.26894488 -1.50504946]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 21
# [[ 4.92191786  0.27437983  0.94199435]
#  [ 1.91141204  1.21894438 -1.42904574]
#  [ 5.70394753  3.26894488 -1.50504946]]
# Exploring.....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 25
# [[ 4.92191786  0.27437983  0.94199435]
#  [ 1.91141204  2.80061339 -1.42904574]
#  [ 5.70394753  3.26894488 -1.50504946]]
# Exploring.....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 29
# [[ 4.92191786  0.27437983  0.94199435]
#  [ 1.91141204  3.68036804 -1.42904574]
#  [ 5.70394753  3.26894488 -1.50504946]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 33
# [[ 4.95315072  0.27437983  0.94199435]
#  [ 1.91141204  3.68036804 -1.42904574]
#  [ 5.70394753  3.26894488 -1.50504946]]
# Exploring.....
# choose  SCISSORS
# Player move : ROCK, bot: SCISSORS, reward: -2, result: LOSE, total_reward: 31
# [[ 4.95315072  0.27437983  0.04139193]
#  [ 1.91141204  3.68036804 -1.42904574]
#  [ 5.70394753  3.26894488 -1.50504946]]
# Exploring.....
# choose  PAPER
# Player move : SCISSORS, bot: PAPER, reward: -2, result: LOSE, total_reward: 29
# [[ 4.95315072  0.27437983  0.04139193]
#  [ 1.91141204  3.68036804 -1.42904574]
#  [ 5.70394753  1.00250924 -1.50504946]]
# Exploring.....
# choose  SCISSORS
# Player move : ROCK, bot: SCISSORS, reward: -2, result: LOSE, total_reward: 27
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 1.91141204  3.68036804 -1.42904574]
#  [ 5.70394753  1.00250924 -1.50504946]]
# Exploring.....
# choose  ROCK
# Player move : PAPER, bot: ROCK, reward: -2, result: LOSE, total_reward: 25
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  3.68036804 -1.42904574]
#  [ 5.70394753  1.00250924 -1.50504946]]
# Exploring.....
# choose  SCISSORS
# Player move : PAPER, bot: SCISSORS, reward: 5, result: WIN, total_reward: 30
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  3.68036804  2.35587189]
#  [ 5.70394753  1.00250924 -1.50504946]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 35
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  3.68036804  2.35587189]
#  [ 5.84728884  1.00250924 -1.50504946]]
# Exploring.....
# choose  SCISSORS
# Player move : SCISSORS, bot: SCISSORS, reward: 4, result: DRAW, total_reward: 39
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  3.68036804  2.35587189]
#  [ 5.84728884  1.00250924  1.83220416]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 43
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  4.20822082  2.35587189]
#  [ 5.84728884  1.00250924  1.83220416]]
# Exploring.....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 47
# [[ 4.95315072  0.27437983 -0.40890928]
#  [ 0.45102109  4.52493249  2.35587189]
#  [ 5.84728884  1.00250924  1.83220416]]
# Exploring.....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 51
# [[ 4.97189043  0.27437983 -0.40890928]
#  [ 0.45102109  4.52493249  2.35587189]
#  [ 5.84728884  1.00250924  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 56
# [[ 4.97189043  0.27437983 -0.40890928]
#  [ 0.45102109  4.52493249  2.35587189]
#  [ 5.92083346  1.00250924  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 61
# [[ 4.97189043  0.27437983 -0.40890928]
#  [ 0.45102109  4.52493249  2.35587189]
#  [ 5.95760577  1.00250924  1.83220416]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 65
# [[ 4.97189043  0.27437983 -0.40890928]
#  [ 0.45102109  4.7149595   2.35587189]
#  [ 5.95760577  1.00250924  1.83220416]]
# Exploring.....
# choose  PAPER
# Player move : SCISSORS, bot: PAPER, reward: -2, result: LOSE, total_reward: 63
# [[ 4.97189043  0.27437983 -0.40890928]
#  [ 0.45102109  4.7149595   2.35587189]
#  [ 5.95760577 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 67
# [[ 4.98313426  0.27437983 -0.40890928]
#  [ 0.45102109  4.7149595   2.35587189]
#  [ 5.95760577 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 72
# [[ 4.98313426  0.27437983 -0.40890928]
#  [ 0.45102109  4.7149595   2.35587189]
#  [ 5.97711631 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 77
# [[ 4.98313426  0.27437983 -0.40890928]
#  [ 0.45102109  4.7149595   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 81
# [[ 4.98313426  0.27437983 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploring.....
# choose  PAPER
# Player move : ROCK, bot: PAPER, reward: 5, result: WIN, total_reward: 86
# [[ 4.98313426  3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 90
# [[ 4.98988055  3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 94
# [[ 4.99392833  3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 98
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.98687158 -0.02724943  1.83220416]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 103
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.99307149 -0.02724943  1.83220416]]
# Exploring.....
# choose  SCISSORS
# Player move : SCISSORS, bot: SCISSORS, reward: 4, result: DRAW, total_reward: 107
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.99307149 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 112
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.99617145 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 117
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.99772142 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 122
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.8289757   2.35587189]
#  [ 5.99849641 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 126
# [[ 4.996357    3.12008748 -0.40890928]
#  [ 0.45102109  4.89738542  2.35587189]
#  [ 5.99849641 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 130
# [[ 4.9978142   3.12008748 -0.40890928]
#  [ 0.45102109  4.89738542  2.35587189]
#  [ 5.99849641 -0.02724943  3.51540923]]
# Exploring.....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 135
# [[ 4.9978142   3.12008748 -0.40890928]
#  [ 0.45102109  4.89738542  2.35587189]
#  [ 5.99902963 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 139
# [[ 4.9978142   3.12008748 -0.40890928]
#  [ 0.45102109  4.93843125  2.35587189]
#  [ 5.99902963 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 144
# [[ 4.9978142   3.12008748 -0.40890928]
#  [ 0.45102109  4.93843125  2.35587189]
#  [ 5.99929623 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 148
# [[ 4.99868852  3.12008748 -0.40890928]
#  [ 0.45102109  4.93843125  2.35587189]
#  [ 5.99929623 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 152
# [[ 4.99868852  3.12008748 -0.40890928]
#  [ 0.45102109  4.96305875  2.35587189]
#  [ 5.99929623 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 156
# [[ 4.99868852  3.12008748 -0.40890928]
#  [ 0.45102109  4.97783525  2.35587189]
#  [ 5.99929623 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 160
# [[ 4.99868852  3.12008748 -0.40890928]
#  [ 0.45102109  4.98670115  2.35587189]
#  [ 5.99929623 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 165
# [[ 4.99868852  3.12008748 -0.40890928]
#  [ 0.45102109  4.98670115  2.35587189]
#  [ 5.99951697 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 169
# [[ 4.99921311  3.12008748 -0.40890928]
#  [ 0.45102109  4.98670115  2.35587189]
#  [ 5.99951697 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 173
# [[ 4.99952787  3.12008748 -0.40890928]
#  [ 0.45102109  4.98670115  2.35587189]
#  [ 5.99951697 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 177
# [[ 4.99952787  3.12008748 -0.40890928]
#  [ 0.45102109  4.99202069  2.35587189]
#  [ 5.99951697 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 182
# [[ 4.99952787  3.12008748 -0.40890928]
#  [ 0.45102109  4.99202069  2.35587189]
#  [ 5.99971127 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 186
# [[ 4.99952787  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99971127 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 191
# [[ 4.99952787  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99980842 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 195
# [[ 4.99971672  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99980842 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 200
# [[ 4.99971672  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99987588 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 205
# [[ 4.99971672  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 209
# [[ 4.99983003  3.12008748 -0.40890928]
#  [ 0.45102109  4.99521241  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 213
# [[ 4.99983003  3.12008748 -0.40890928]
#  [ 0.45102109  4.99712745  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 217
# [[ 4.99983003  3.12008748 -0.40890928]
#  [ 0.45102109  4.99827647  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 221
# [[ 4.99989802  3.12008748 -0.40890928]
#  [ 0.45102109  4.99827647  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 225
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99827647  2.35587189]
#  [ 5.99990961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 230
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99827647  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 234
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99896588  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 238
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99937953  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 242
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99962772  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 246
# [[ 4.99993881  3.12008748 -0.40890928]
#  [ 0.45102109  4.99977663  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 250
# [[ 4.99996329  3.12008748 -0.40890928]
#  [ 0.45102109  4.99977663  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 254
# [[ 4.99997797  3.12008748 -0.40890928]
#  [ 0.45102109  4.99977663  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 258
# [[ 4.99997797  3.12008748 -0.40890928]
#  [ 0.45102109  4.99986598  2.35587189]
#  [ 5.99994869 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 263
# [[ 4.99997797  3.12008748 -0.40890928]
#  [ 0.45102109  4.99986598  2.35587189]
#  [ 5.99997214 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 267
# [[ 4.99998678  3.12008748 -0.40890928]
#  [ 0.45102109  4.99986598  2.35587189]
#  [ 5.99997214 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 272
# [[ 4.99998678  3.12008748 -0.40890928]
#  [ 0.45102109  4.99986598  2.35587189]
#  [ 5.99998475 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 277
# [[ 4.99998678  3.12008748 -0.40890928]
#  [ 0.45102109  4.99986598  2.35587189]
#  [ 5.99999105 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 281
# [[ 4.99998678  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999105 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 285
# [[ 4.99999207  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999105 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 289
# [[ 4.99999524  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999105 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 293
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999105 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 298
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999524 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 303
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99991959  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 307
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99995175  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 311
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99997105  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 315
# [[ 4.99999715  3.12008748 -0.40890928]
#  [ 0.45102109  4.99998263  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 319
# [[ 4.99999829  3.12008748 -0.40890928]
#  [ 0.45102109  4.99998263  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 323
# [[ 4.99999829  3.12008748 -0.40890928]
#  [ 0.45102109  4.99998958  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 327
# [[ 4.99999897  3.12008748 -0.40890928]
#  [ 0.45102109  4.99998958  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 331
# [[ 4.99999897  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999375  2.35587189]
#  [ 5.99999733 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 336
# [[ 4.99999897  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999375  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 340
# [[ 4.99999938  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999375  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 344
# [[ 4.99999963  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999375  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 348
# [[ 4.99999963  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999625  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 352
# [[ 4.99999963  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999775  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 356
# [[ 4.99999978  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999775  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 360
# [[ 4.99999978  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999865  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 364
# [[ 4.99999978  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999856 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 369
# [[ 4.99999978  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999926 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 374
# [[ 4.99999978  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 378
# [[ 4.99999987  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 382
# [[ 4.99999992  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 386
# [[ 4.99999995  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999919  2.35587189]
#  [ 5.99999961 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 390
# [[ 4.99999995  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999951  2.35587189]
#  [ 5.99999961 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 395
# [[ 4.99999995  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999951  2.35587189]
#  [ 5.9999998  -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 400
# [[ 4.99999995  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999951  2.35587189]
#  [ 5.99999989 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 404
# [[ 4.99999997  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999951  2.35587189]
#  [ 5.99999989 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 408
# [[ 4.99999997  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999971  2.35587189]
#  [ 5.99999989 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 412
# [[ 4.99999998  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999971  2.35587189]
#  [ 5.99999989 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 417
# [[ 4.99999998  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999971  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 421
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999971  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 425
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999982  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 429
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999982  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 433
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999989  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 437
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999994  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 441
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999996  2.35587189]
#  [ 5.99999995 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 446
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999996  2.35587189]
#  [ 5.99999997 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 451
# [[ 4.99999999  3.12008748 -0.40890928]
#  [ 0.45102109  4.99999996  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 455
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999996  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 459
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999996  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 463
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999998  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 467
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999999  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 471
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999999  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 475
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999999  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 479
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999999  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 484
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  4.99999999  2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 488
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 492
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 496
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 5.99999999 -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 501
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 505
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 510
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 514
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 519
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 524
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 528
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 532
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 536
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 540
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 544
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 548
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 552
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 557
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 562
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 567
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 571
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 575
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 580
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 584
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 588
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 592
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 596
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 600
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 604
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 608
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 612
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 616
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 620
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 625
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 629
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 633
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 638
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 643
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 647
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 651
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 655
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 660
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 664
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 668
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 672
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 676
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 680
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 684
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 689
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 694
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 699
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 703
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 708
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 712
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 717
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 722
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 726
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 730
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 734
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 738
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 742
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 746
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 751
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 755
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 760
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 765
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 769
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 773
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 777
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 781
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 786
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 790
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 794
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : ROCK, bot: ROCK, reward: 4, result: DRAW, total_reward: 798
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 803
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 807
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 811
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 816
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  ROCK
# Player move : SCISSORS, bot: ROCK, reward: 5, result: WIN, total_reward: 821
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
# Exploiting....
# choose  PAPER
# Player move : PAPER, bot: PAPER, reward: 4, result: DRAW, total_reward: 825
# [[ 5.          3.12008748 -0.40890928]
#  [ 0.45102109  5.          2.35587189]
#  [ 6.         -0.02724943  3.51540923]]
